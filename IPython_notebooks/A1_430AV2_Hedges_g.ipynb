# %% [markdown]
# # Calculations of the Effect Size (ES) for each microarray study
#
# ###  Using Hedges' g value, an adjusted Cohen's d  value

# %% [markdown]
# $$  {Enrichment} = \bar{X_1}-\bar{X_2}$$
#
# where group1 is SCN Expression values and group2 are Whole Brain Expression values
# (SCN mean - WB mean) **(Logged values, so minus gives ratio)**

# %% [markdown]
# $$  {Pooled\ Standard\  Deviantion} = \sqrt\frac{(n_1-1)S_1^2 +(n_2-1)S_2^2}{(n_2 +n_2) -2}  $$

# %% [markdown]
# $$  {Cohen's\ d\ value} = \frac{Enrichment}{Pooled\ Standard\ Deviation} $$

# %% [markdown]
# $$  {Correction\ Factor (J\ Factor)} = 1- \frac{3}{4df-1} $$

# %% [markdown]
# $$  {Hedges'\ g\ value} = Cohen's\ d\ \text{x}\ J\ $$

# %% [markdown]
# $$  {Variance\ in\ d (V_d)} = \frac{n_1- +n_2}{n_1 n_2} + \frac{d^2}{2(n_1 +n_2)}  $$

# %% [markdown]
# $$  {Variance\ in\ g (V_g)} = J^2\  \text{x}\ V_d  $$

# %% [markdown]
# $$  {Standard\ Error\ in\ g (SE_g)} = \sqrt{V_g}  $$

# %% [markdown]
# ## Setup working environment and import data

# %%
import pandas as pd # Dataframes and file IO
import numpy as np # numerical calculations

# %%
prefix = '430AV2_'   # define a prefix to add to column names (making indexing easier later)

# %%
df=pd.read_table('../AltAnalyze_output/DATASET-430aV2.txt', delimiter='\t',  index_col=0) #,nrows=500)  
df.shape
# Out:
# (22690, 32)

# %%
# remove probes that are know to cross-hybridise to more than one target
df =df[~df.index.str.contains('_x_|_s_')]    #   important reverse selector ~ 
df.shape
# Out:
# (19706, 32)

# %% [markdown]
# ## Look at column names and then setup filters for grouping columns into SCN and WB groups

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM159292.CEL', 'GSM159293.CEL',
#        'GSM159294.CEL', 'avg-SCN', 'log_fold-SCN_vs_WB', 'fold-SCN_vs_WB',
#        'rawp-SCN_vs_WB', 'adjp-SCN_vs_WB', 'GSM189596.CEL', 'GSM189598.CEL',
#        'GSM189600.CEL', 'GSM189602.CEL', 'GSM189628.CEL', 'GSM189630.CEL',
#        'GSM189632.CEL', 'GSM189634.CEL', 'avg-WB', 'ANOVA-rawp', 'ANOVA-adjp',
#        'largest fold'],
#       dtype='object')

# %%
# define regular expressions for filters 
scn_filt ='159'
wb_filt ='189'

# %%
df_scn=df.filter(regex= scn_filt)
df_scn.shape
# Out:
# (19706, 3)

# %%
df_wb=df.filter(regex= wb_filt)
df_wb.shape
# Out:
# (19706, 8)

# %% [markdown]
# ## Calculations

# %%
SCNcount = df.filter(regex=scn_filt).count(axis=1)

# %%
# Enrichment

df[prefix+'Enrich'] = df.filter(regex=scn_filt).mean(axis=1) - df.filter(regex=wb_filt).mean(axis=1)

# %%
df[prefix+'Enrich'].head()
# Out:
# Probesets
# 1427138_at      0.564749
# 1425600_a_at   -0.880608
# 1450135_at      0.743188
# 1434334_at      0.043725
# 1435780_at     -2.279606
# Name: 430AV2_Enrich, dtype: float64

# %%
# Pooled StDev
SCNcount = df.filter(regex=scn_filt).count(axis=1)
WBcount = df.filter(regex=wb_filt).count(axis=1)

StdevSCN = (SCNcount-1) * df.filter(regex=scn_filt).var(axis=1)
StdevWB = (WBcount-1) * df.filter(regex=wb_filt).var(axis=1)

df[prefix+'poolStDev'] = np.sqrt((StdevSCN+StdevWB)/(SCNcount+ WBcount-2))

# %%
#Cohen's d

df[prefix+'Cohens_d'] = df[prefix+'Enrich'] / df[prefix+'poolStDev']

# %%
#df[prefix+'poolStDev'].head()
df[prefix+'Cohens_d'] .head()
# Out:
# Probesets
# 1427138_at       2.856382
# 1425600_a_at    -3.731278
# 1450135_at       1.893515
# 1434334_at       0.129605
# 1435780_at     -10.571958
# Name: 430AV2_Cohens_d, dtype: float64

# %%
#J value (Correction factor)

df[prefix+'J'] = 1-(3/(4*(SCNcount+WBcount-1)))

# %%
#Hedge's g

df[prefix+'Hedges_g'] = df[prefix+'Cohens_d'] * df[prefix+'J']

# %%
#df[prefix+'J'].head()
df[prefix+'Hedges_g'] .head()
# Out:
# Probesets
# 1427138_at      2.642153
# 1425600_a_at   -3.451432
# 1450135_at      1.751501
# 1434334_at      0.119885
# 1435780_at     -9.779061
# Name: 430AV2_Hedges_g, dtype: float64

# %%
#Var_d
SCNcount = df.filter(regex=scn_filt).count(axis=1)
WBcount = df.filter(regex=wb_filt).count(axis=1)

Ftop1 = SCNcount + WBcount
Ftop2 = SCNcount * WBcount
Fbottom1 = np.square(df[prefix+'Cohens_d']) 
Fbottom2 =  2*(SCNcount + WBcount)


df[prefix+'Var_d'] = (Ftop1/Ftop2) + (Fbottom1 /Fbottom2)

# %%
#check output
df[prefix+'Var_d'].head()
# Out:
# Probesets
# 1427138_at      0.829193
# 1425600_a_at    1.091171
# 1450135_at      0.621306
# 1434334_at      0.459097
# 1435780_at      5.538620
# Name: 430AV2_Var_d, dtype: float64

# %%
df[prefix+'Var_g'] = df[prefix+'Var_d'] * np.square(df[prefix+'J'])

# %%
#SEg
df[prefix+'SEg'] = np.sqrt(df[prefix+'Var_g'])

# %%
df.sort_values(by='430AV2_Hedges_g', ascending=False, inplace=True)
df
# Out:
#                                                          Symbol  \
# Probesets
# 1419408_at                                                 Six6
# 1427198_at                                             BC022960
# 1417765_a_at                                               Amy1
# 1429982_at                                               Rimklb
# 1436172_at                                           9530028C05
# 1417704_a_at                                            Arhgap6
# 1425603_at                                             Tmem176a
# 1455696_a_at                                             Prpf4b
# 1455265_a_at                                              Rgs16
# 1427676_a_at                                              Grik1
# 1417058_a_at                                            Krtcap2
# 1454842_a_at                                           B3galnt2
# 1425241_a_at                                               Wsb1
# 1429041_at                                        6820431F20Rik
# 1455222_a_at                                               Ubp1
# 1418225_at                                                Orc2l
# 1422673_at                                                Prkd1
# 1423530_at                                               Stk32c
# 1453025_at                                              Macrod2
# 1460373_a_at                                              Setd4
# 1449061_a_at                                              Prim1
# 1452473_at                                                Prr15
# 1448848_at                                                Tor1b
# 1417360_at                                                 Mlh1
# 1450688_at                                                 Rgl2
# 1428357_at                                        2610019F03Rik
# 1439476_at                                                 Dsg2
# 1418603_at                                               Avpr1a
# 1423312_at                                                 Tpbg
# 1426536_at                                                Narg2
# ...                                                         ...
# 1450970_at                                                 Got1
# 1452184_at                                               Ndufb9
# 1416781_at                                                Praf2
# 1426710_at                                                Calm3
# 1416243_a_at  100038991 /// 100043296 /// ENSMUSG00000069439...
# 1420611_at                                               Prkacb
# 1428379_at                                              Slc17a6
# 1417653_at                                                Pvalb
# 1416112_at                                                Cox8a
# 1416971_at                                               Cox7a2
# 1416277_a_at                                              Rplp1
# 1415970_at                                                Cox6c
# 1415819_a_at                                            Ppp2r1a
# 1420871_at                                              Gucy1b3
# 1450088_a_at                                               Mobp
# 1422576_at                                               Atxn10
# 1416829_at                                                Atp5b
# 1450875_at                                                Gpr37
# 1423652_at                                                Isca1
# 1421813_a_at                                               Psap
# 1423281_at                                                Stmn2
# 1453729_a_at                                              Rpl37
# 1418000_a_at                                              Itm2b
# 1423409_a_at                                      2500003M10Rik
# 1451961_a_at                                                Mbp
# 1416269_at                                               Atp5j2
# 1425467_a_at                                               Plp1
# 1417502_at                                               Tspan7
# 1415906_at                                               Tmsb4x
# 1426313_at                                                  Bre
#
#                                                      Definition  \
# Probesets
# 1419408_at    sine oculis-related homeobox 6 homolog (Drosop...
# 1427198_at                               cDNA sequence BC022960
# 1417765_a_at                                amylase 1, salivary
# 1429982_at                           RIKEN cDNA 4933426K21 gene
# 1436172_at                                predicted gene, 20559
# 1417704_a_at                    Rho GTPase activating protein 6
# 1425603_at                           transmembrane protein 176A
# 1455696_a_at  PRP4 pre-mRNA processing factor 4 homolog B (y...
# 1455265_a_at                regulator of G-protein signaling 16
# 1427676_a_at          glutamate receptor, ionotropic, kainate 1
# 1417058_a_at                  keratinocyte associated protein 2
# 1454842_a_at  UDP-GalNAc:betaGlcNAc beta 1,3-galactosaminylt...
# 1425241_a_at                WD repeat and SOCS box-containing 1
# 1429041_at                           RIKEN cDNA 6820431F20 gene
# 1455222_a_at                         upstream binding protein 1
# 1418225_at    origin recognition complex, subunit 2-like (S....
# 1422673_at                                 protein kinase C, mu
# 1423530_at                          serine/threonine kinase 32C
# 1453025_at                           RIKEN cDNA 2900006F19 gene
# 1460373_a_at                            SET domain containing 4
# 1449061_a_at                           DNA primase, p49 subunit
# 1452473_at                                      proline rich 15
# 1448848_at                            torsin family 1, member B
# 1417360_at                             mutL homolog 1 (E. coli)
# 1450688_at    ral guanine nucleotide dissociation stimulator...
# 1428357_at                           RIKEN cDNA 2610019F03 gene
# 1439476_at                                         desmoglein 2
# 1418603_at                     arginine vasopressin receptor 1A
# 1423312_at                             trophoblast glycoprotein
# 1426536_at                       NMDA receptor-regulated gene 2
# ...                                                         ...
# 1450970_at       glutamate oxaloacetate transaminase 1, soluble
# 1452184_at    NADH dehydrogenase (ubiquinone) 1 beta subcomp...
# 1416781_at                                 PRA1 domain family 2
# 1416243_a_at  ENSMUSG00000083911|ENSMUSG00000069439|ENSMUSG0...
# 1420611_at                                   ENSMUSG00000005034
# 1428379_at                                   ENSMUSG00000030500
# 1417653_at                                   ENSMUSG00000005716
# 1416112_at                                   ENSMUSG00000035885
# 1416971_at                                   ENSMUSG00000032330
# 1416277_a_at  ENSMUSG00000007892|ENSMUSG00000094344|ENSMUSG0...
# 1415970_at                                   ENSMUSG00000014313
# 1415819_a_at                                 ENSMUSG00000007564
# 1420871_at                                   ENSMUSG00000028005
# 1450088_a_at                                 ENSMUSG00000032517
# 1422576_at                                   ENSMUSG00000016541
# 1416829_at                                   ENSMUSG00000025393
# 1450875_at                                   ENSMUSG00000039904
# 1423652_at    ENSMUSG00000078139|ENSMUSG00000044792|ENSMUSG0...
# 1421813_a_at                                 ENSMUSG00000004207
# 1423281_at                                   ENSMUSG00000027500
# 1453729_a_at              ENSMUSG00000041841|ENSMUSG00000072692
# 1418000_a_at                                 ENSMUSG00000022108
# 1423409_a_at              ENSMUSG00000051548|ENSMUSG00000001017
# 1451961_a_at                                 ENSMUSG00000041607
# 1416269_at                                   ENSMUSG00000038690
# 1425467_a_at                                 ENSMUSG00000031425
# 1417502_at                                   ENSMUSG00000058254
# 1415906_at                                   ENSMUSG00000049775
# 1426313_at                                   ENSMUSG00000052139
#
#                                         Entrez_id Unigene_id  \
# Probesets
# 1419408_at                                  20476        NaN
# 1427198_at                                 237246        NaN
# 1417765_a_at                                11722        NaN
# 1429982_at                                 108653        NaN
# 1436172_at                                 330256        NaN
# 1417704_a_at                                11856        NaN
# 1425603_at                                  66058        NaN
# 1455696_a_at                                19134        NaN
# 1455265_a_at                                19734        NaN
# 1427676_a_at                                14805        NaN
# 1417058_a_at                                66059        NaN
# 1454842_a_at                                97884        NaN
# 1425241_a_at                                78889        NaN
# 1429041_at                                 381598        NaN
# 1455222_a_at                                22221        NaN
# 1418225_at                                  18393        NaN
# 1422673_at                                  18760        NaN
# 1423530_at                                  57740        NaN
# 1453025_at                                  72899        NaN
# 1460373_a_at                               224440        NaN
# 1449061_a_at                                19075        NaN
# 1452473_at                                  78004        NaN
# 1448848_at                                  30934        NaN
# 1417360_at                                  17350        NaN
# 1450688_at                                  19732        NaN
# 1428357_at                                  72148        NaN
# 1439476_at                                  13511        NaN
# 1418603_at                                  54140        NaN
# 1423312_at                                  21983        NaN
# 1426536_at                                  93697        NaN
# ...                                           ...        ...
# 1450970_at                                  14718        NaN
# 1452184_at                                  66218        NaN
# 1416781_at                                  54637        NaN
# 1426710_at                      12314|12315|12313        NaN
# 1416243_a_at  100038991|66489|100040823|100043296        NaN
# 1420611_at                                  18749        NaN
# 1428379_at                                 140919        NaN
# 1417653_at                                  19293        NaN
# 1416112_at                        12868|100048483        NaN
# 1416971_at                                  12866        NaN
# 1416277_a_at                         56040|279067        NaN
# 1415970_at                           12864|621837        NaN
# 1415819_a_at                                51792        NaN
# 1420871_at                                  54195        NaN
# 1450088_a_at                                17433        NaN
# 1422576_at                                  54138        NaN
# 1416829_at                                  11947        NaN
# 1450875_at                                  14763        NaN
# 1423652_at                                  69046        NaN
# 1421813_a_at                                19156        NaN
# 1423281_at                                  20257        NaN
# 1453729_a_at                      67281|100502825        NaN
# 1418000_a_at                                16432        NaN
# 1423409_a_at                                66511        NaN
# 1451961_a_at                                17196        NaN
# 1416269_at                                  57423        NaN
# 1425467_a_at                                18823        NaN
# 1417502_at                                  21912        NaN
# 1415906_at                                  19241        NaN
# 1426313_at                                 107976        NaN
#
#                                                      GO-Process  \
# Probesets
# 1419408_at    multicellular organismal development // regula...
# 1427198_at                                                  NaN
# 1417765_a_at  metabolic process // carbohydrate metabolic pr...
# 1429982_at                         protein modification process
# 1436172_at                                                  NaN
# 1417704_a_at  regulation of GTPase activity // signal transd...
# 1425603_at      platelet activating factor biosynthetic process
# 1455696_a_at  protein amino acid phosphorylation // RNA spli...
# 1455265_a_at  G-protein coupled receptor protein signaling p...
# 1427676_a_at  adult behavior // positive regulation of gamma...
# 1417058_a_at  protein amino acid N-linked glycosylation via ...
# 1454842_a_at  UDP-N-acetylgalactosamine metabolic process //...
# 1425241_a_at  ubiquitin-dependent protein catabolic process ...
# 1429041_at                             homophilic cell adhesion
# 1455222_a_at  transcription // angiogenesis // regulation of...
# 1418225_at                                      DNA replication
# 1422673_at    protein amino acid phosphorylation // intracel...
# 1423530_at                   protein amino acid phosphorylation
# 1453025_at                                                  NaN
# 1460373_a_at                                                NaN
# 1449061_a_at  transcription // DNA replication // DNA replic...
# 1452473_at                 multicellular organismal development
# 1448848_at         chaperone cofactor-dependent protein folding
# 1417360_at    resolution of meiotic joint molecules as recom...
# 1450688_at    signal transduction // regulation of small GTP...
# 1428357_at                                                  NaN
# 1439476_at            cell adhesion // homophilic cell adhesion
# 1418603_at    G-protein coupled receptor protein signaling p...
# 1423312_at                                                  NaN
# 1426536_at                                                  NaN
# ...                                                         ...
# 1450970_at    biosynthetic process // fatty acid homeostasis...
# 1452184_at                electron transport chain // transport
# 1416781_at                       transport // protein transport
# 1426710_at     positive regulation of DNA binding // cell cycle
# 1416243_a_at                                        translation
# 1420611_at    protein amino acid phosphorylation // G-protei...
# 1428379_at    ion transport // neurotransmitter uptake // so...
# 1417653_at                                                  NaN
# 1416112_at                                                  NaN
# 1416971_at                                                  NaN
# 1416277_a_at            translational elongation // translation
# 1415970_at                                                  NaN
# 1415819_a_at                                                NaN
# 1420871_at    cGMP biosynthetic process // cyclic nucleotide...
# 1450088_a_at                                                NaN
# 1422576_at                           nervous system development
# 1416829_at    ATP biosynthetic process // ATP synthesis coup...
# 1450875_at    signal transduction // G-protein coupled recep...
# 1423652_at                         iron-sulfur cluster assembly
# 1421813_a_at  lipid metabolic process // sphingolipid metabo...
# 1423281_at                      intracellular signaling cascade
# 1453729_a_at                                        translation
# 1418000_a_at                apoptosis // induction of apoptosis
# 1423409_a_at                                                NaN
# 1451961_a_at                                        myelination
# 1416269_at    ion transport // ATP biosynthetic process // t...
# 1425467_a_at  myelination // cell maturation // long-chain f...
# 1417502_at                                                  NaN
# 1415906_at    cytoskeleton organization // actin cytoskeleto...
# 1426313_at    apoptosis // ubiquitin-dependent protein catab...
#
#                                                     GO-Function  \
# Probesets
# 1419408_at    transcription factor activity // DNA binding /...
# 1427198_at                                                  NaN
# 1417765_a_at  calcium ion binding // hydrolase activity, act...
# 1429982_at    manganese ion binding // catalytic activity //...
# 1436172_at                                                  NaN
# 1417704_a_at  Rho GTPase activator activity // GTPase activa...
# 1425603_at    diacylglycerol cholinephosphotransferase activity
# 1455696_a_at  transferase activity // protein kinase activit...
# 1455265_a_at  signal transducer activity // GTPase activator...
# 1427676_a_at  protein binding // extracellular-glutamate-gat...
# 1417058_a_at  dolichyl-diphosphooligosaccharide-protein glyc...
# 1454842_a_at  transferase activity, transferring glycosyl gr...
# 1425241_a_at                                    protein binding
# 1429041_at                                  calcium ion binding
# 1455222_a_at                                        DNA binding
# 1418225_at    DNA replication origin binding // protein binding
# 1422673_at    diacylglycerol binding // protein kinase C act...
# 1423530_at    magnesium ion binding // transferase activity ...
# 1453025_at                                                  NaN
# 1460373_a_at                                                NaN
# 1449061_a_at  transferase activity // zinc ion binding // nu...
# 1452473_at                                                  NaN
# 1448848_at    nucleoside-triphosphatase activity // nucleoti...
# 1417360_at    mismatched DNA binding // single-stranded DNA ...
# 1450688_at    thyroid hormone receptor coactivator activity ...
# 1428357_at                                                  NaN
# 1439476_at               calcium ion binding // protein binding
# 1418603_at    peptide hormone binding // vasopressin recepto...
# 1423312_at                                      protein binding
# 1426536_at                                    receptor activity
# ...                                                         ...
# 1450970_at    transaminase activity // pyridoxal phosphate b...
# 1452184_at                                                  NaN
# 1416781_at                                                  NaN
# 1426710_at    calcium ion binding // protein binding // N-te...
# 1416243_a_at                 structural constituent of ribosome
# 1420611_at    magnesium ion binding // transferase activity ...
# 1428379_at    transporter activity // symporter activity // ...
# 1417653_at                                  calcium ion binding
# 1416112_at                        cytochrome-c oxidase activity
# 1416971_at    electron carrier activity // cytochrome-c oxid...
# 1416277_a_at                 structural constituent of ribosome
# 1415970_at                        cytochrome-c oxidase activity
# 1415819_a_at                         protein binding // binding
# 1420871_at    lyase activity // phosphorus-oxygen lyase acti...
# 1450088_a_at            structural constituent of myelin sheath
# 1422576_at                           protein binding // binding
# 1416829_at    eukaryotic cell surface binding // MHC class I...
# 1450875_at    receptor activity // signal transducer activit...
# 1423652_at    iron-sulfur cluster binding // metal ion bindi...
# 1421813_a_at                                                NaN
# 1423281_at                                      protein binding
# 1453729_a_at  RNA binding // rRNA binding // metal ion bindi...
# 1418000_a_at                     protein binding // ATP binding
# 1423409_a_at                                                NaN
# 1451961_a_at            structural constituent of myelin sheath
# 1416269_at    metal ion binding // hydrogen ion transmembran...
# 1425467_a_at  protein binding // structural constituent of m...
# 1417502_at                                                  NaN
# 1415906_at                     protein binding // actin binding
# 1426313_at    protein binding // tumor necrosis factor recep...
#
#                                                    GO-Component  \
# Probesets
# 1419408_at                                              nucleus
# 1427198_at                                                  NaN
# 1417765_a_at        extracellular region // extracellular space
# 1429982_at                                                  NaN
# 1436172_at                                                  NaN
# 1417704_a_at   cytoplasm // intracellular // actin cytoskeleton
# 1425603_at                     integral to membrane // membrane
# 1455696_a_at               spliceosome // nucleus // chromosome
# 1455265_a_at                                          cytoplasm
# 1427676_a_at  postsynaptic membrane // synapse // kainate se...
# 1417058_a_at  oligosaccharyltransferase complex // integral ...
# 1454842_a_at  Golgi membrane // Golgi apparatus // integral ...
# 1425241_a_at                                      intracellular
# 1429041_at                                             membrane
# 1455222_a_at                                            nucleus
# 1418225_at    nuclear origin of replication recognition comp...
# 1422673_at                                                  NaN
# 1423530_at                                                  NaN
# 1453025_at                                                  NaN
# 1460373_a_at                                            nucleus
# 1449061_a_at               alpha DNA polymerase:primase complex
# 1452473_at                                                  NaN
# 1448848_at    cytoplasm // endoplasmic reticulum lumen // en...
# 1417360_at    male germ cell nucleus // synaptonemal complex...
# 1450688_at                                        intracellular
# 1428357_at                                                  NaN
# 1439476_at    desmosome // plasma membrane // cell junction ...
# 1418603_at    plasma membrane // integral to membrane // mem...
# 1423312_at    cytoplasm // endoplasmic reticulum // integral...
# 1426536_at                                              nucleus
# ...                                                         ...
# 1450970_at                                 cytosol // cytoplasm
# 1452184_at    mitochondrion // mitochondrial inner membrane ...
# 1416781_at    endosome membrane // endosome // integral to m...
# 1426710_at                                              spindle
# 1416243_a_at  ribosome // intracellular // ribonucleoprotein...
# 1420611_at    cytosol // cytoplasm // cAMP-dependent protein...
# 1428379_at    synaptosome // synapse // cytoplasmic vesicle ...
# 1417653_at                                    axon // cytoplasm
# 1416112_at    mitochondrion // mitochondrial inner membrane ...
# 1416971_at    mitochondrion // mitochondrial inner membrane ...
# 1416277_a_at  ribosome // intracellular // ribonucleoprotein...
# 1415970_at    mitochondrion // mitochondrial inner membrane ...
# 1415819_a_at     cytosol // protein phosphatase type 2A complex
# 1420871_at                                            cytoplasm
# 1450088_a_at                         mitochondrion // cytoplasm
# 1422576_at    dendrite // cytoplasm // perinuclear region of...
# 1416829_at    proton-transporting two-sector ATPase complex,...
# 1450875_at    endoplasmic reticulum membrane // endoplasmic ...
# 1423652_at                                        mitochondrion
# 1421813_a_at  extracellular region // mitochondrion // lysosome
# 1423281_at    cytoplasm // cell projection // growth cone //...
# 1453729_a_at  ribosome // intracellular // ribonucleoprotein...
# 1418000_a_at  membrane fraction // Golgi membrane // Golgi a...
# 1423409_a_at                                                NaN
# 1451961_a_at  cell soma // internode region of axon // cytop...
# 1416269_at    mitochondrion // mitochondrial inner membrane ...
# 1425467_a_at  myelin sheath // membrane // integral to membr...
# 1417502_at                     integral to membrane // membrane
# 1415906_at      cytosol // cytoplasm // cytoskeleton // nucleus
# 1426313_at    nuclear ubiquitin ligase complex // nucleus //...
#
#                                                    Pathway_info  \
# Probesets
# 1419408_at                                                  NaN
# 1427198_at                                                  NaN
# 1417765_a_at                                                NaN
# 1429982_at                                                  NaN
# 1436172_at                                                  NaN
# 1417704_a_at                                                NaN
# 1425603_at                                                  NaN
# 1455696_a_at  GenMAPP-mRNA_processing_binding_Reactome // mR...
# 1455265_a_at  GenMAPP-Calcium_regulation_in_cardiac_cells //...
# 1427676_a_at                                                NaN
# 1417058_a_at                                                NaN
# 1454842_a_at                                                NaN
# 1425241_a_at                                                NaN
# 1429041_at                                                  NaN
# 1455222_a_at                                                NaN
# 1418225_at    G1 to S cell cycle control:WP413(WikiPathways)...
# 1422673_at    GenMAPP-G_Protein_Signaling // GenMAPP-Calcium...
# 1423530_at                                                  NaN
# 1453025_at                                                  NaN
# 1460373_a_at                                                NaN
# 1449061_a_at  G1 to S cell cycle control:WP413(WikiPathways)...
# 1452473_at                                                  NaN
# 1448848_at                                                  NaN
# 1417360_at    GenMAPP-Ovarian_Infertility_Genes // Mismatch ...
# 1450688_at                                                  NaN
# 1428357_at                                                  NaN
# 1439476_at                                                  NaN
# 1418603_at    GPCRs, Class A Rhodopsin-like:WP189(WikiPathwa...
# 1423312_at                                                  NaN
# 1426536_at                                                  NaN
# ...                                                         ...
# 1450970_at    GenMAPP-Glycolysis_and_Gluconeogenesis // Alan...
# 1452184_at    Electron Transport Chain:WP295(WikiPathways) /...
# 1416781_at                                                  NaN
# 1426710_at    G13 Signaling Pathway:WP298(WikiPathways) // E...
# 1416243_a_at  Cytoplasmic Ribosomal Proteins:WP163(WikiPathw...
# 1420611_at    GenMAPP-G_Protein_Signaling // GenMAPP-Calcium...
# 1428379_at                                                  NaN
# 1417653_at                                                  NaN
# 1416112_at    Electron Transport Chain:WP295(WikiPathways) /...
# 1416971_at    Electron Transport Chain:WP295(WikiPathways) /...
# 1416277_a_at  Cytoplasmic Ribosomal Proteins:WP163(WikiPathw...
# 1415970_at         Electron Transport Chain:WP295(WikiPathways)
# 1415819_a_at  IL-6 signaling Pathway:WP387(WikiPathways) // ...
# 1420871_at    Purine metabolism:KEGG-mmu00230:WP2185(WikiPat...
# 1450088_a_at                                                NaN
# 1422576_at                                                  NaN
# 1416829_at    Electron Transport Chain:WP295(WikiPathways) /...
# 1450875_at    GPCRs, Class A Rhodopsin-like:WP189(WikiPathwa...
# 1423652_at                                                  NaN
# 1421813_a_at                                                NaN
# 1423281_at                                                  NaN
# 1453729_a_at  GenMAPP-mRNA_processing_binding_Reactome // Cy...
# 1418000_a_at                                                NaN
# 1423409_a_at                                                NaN
# 1451961_a_at  MAPK Cascade:WP251(WikiPathways) // GenMAPP-MA...
# 1416269_at    Electron Transport Chain:WP295(WikiPathways) /...
# 1425467_a_at                                                NaN
# 1417502_at    XPodNet - protein-protein interactions in the ...
# 1415906_at    Regulation of Actin Cytoskeleton:WP523(WikiPat...
# 1426313_at                                                  NaN
#
#                                 Putative microRNA binding sites     ...      \
# Probesets                                                           ...
# 1419408_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...     ...
# 1427198_at                                                  NaN     ...
# 1417765_a_at                                                NaN     ...
# 1429982_at    mmu-let-7d(miRanda), mmu-let-7f(miRanda), mmu-...     ...
# 1436172_at                                                  NaN     ...
# 1417704_a_at  mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...     ...
# 1425603_at                                                  NaN     ...
# 1455696_a_at                                                NaN     ...
# 1455265_a_at  mmu-let-7(TargetScan), mmu-let-7a(miRanda|pict...     ...
# 1427676_a_at  mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...     ...
# 1417058_a_at  mmu-miR-137(miRanda), mmu-miR-181a(miRanda), m...     ...
# 1454842_a_at  mmu-let-7e(miRanda), mmu-miR-1(miRanda), mmu-m...     ...
# 1425241_a_at  mmu-miR-101(TargetScan|pictar), mmu-miR-101a(R...     ...
# 1429041_at                                                  NaN     ...
# 1455222_a_at  mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...     ...
# 1418225_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...     ...
# 1422673_at    mmu-miR-101b(RNAhybrid|miRanda), mmu-miR-106a(...     ...
# 1423530_at    mmu-miR-139-5p(miRanda), mmu-miR-146a(miRanda)...     ...
# 1453025_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...     ...
# 1460373_a_at                                                NaN     ...
# 1449061_a_at  mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...     ...
# 1452473_at    mmu-miR-106a(miRanda), mmu-miR-106ab(TargetSca...     ...
# 1448848_at    mmu-miR-103(miRanda), mmu-miR-105(TargetScan),...     ...
# 1417360_at    mmu-miR-101a(RNAhybrid|miRanda), mmu-miR-103(R...     ...
# 1450688_at    mmu-let-7a(miRanda), mmu-let-7b(RNAhybrid|miRa...     ...
# 1428357_at    mmu-let-7a(miRanda), mmu-let-7d(miRanda), mmu-...     ...
# 1439476_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...     ...
# 1418603_at    mmu-let-7d(miRanda), mmu-miR-10a(miRanda), mmu...     ...
# 1423312_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...     ...
# 1426536_at    mmu-let-7d(miRanda), mmu-let-7e(miRanda), mmu-...     ...
# ...                                                         ...     ...
# 1450970_at    mmu-miR-1192(miRanda), mmu-miR-214(miRanda), m...     ...
# 1452184_at    mmu-miR-103(RNAhybrid|miRanda), mmu-miR-125b(R...     ...
# 1416781_at    mmu-miR-133a(miRanda), mmu-miR-133b(miRanda), ...     ...
# 1426710_at    mmu-miR-1(pictar), mmu-miR-122(TargetScan|miRa...     ...
# 1416243_a_at                                                NaN     ...
# 1420611_at    mmu-let-7a(miRanda), mmu-let-7c(miRanda), mmu-...     ...
# 1428379_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7c(RNAh...     ...
# 1417653_at    mmu-miR-1192(miRanda), mmu-miR-16(miRanda), mm...     ...
# 1416112_at    mmu-miR-134(miRanda), mmu-miR-214(miRanda), mm...     ...
# 1416971_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...     ...
# 1416277_a_at  mmu-miR-1192(miRanda), mmu-miR-24(RNAhybrid|mi...     ...
# 1415970_at    mmu-miR-129-5p(miRanda), mmu-miR-186(miRanda),...     ...
# 1415819_a_at  mmu-let-7b(RNAhybrid|miRanda), mmu-miR-103(RNA...     ...
# 1420871_at    mmu-miR-1192(miRanda), mmu-miR-128(miRanda), m...     ...
# 1450088_a_at  mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(miRa...     ...
# 1422576_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...     ...
# 1416829_at    mmu-miR-103(RNAhybrid|miRanda), mmu-miR-10a(mi...     ...
# 1450875_at    mmu-miR-1192(miRanda), mmu-miR-124(miRanda), m...     ...
# 1423652_at                                                  NaN     ...
# 1421813_a_at  mmu-miR-130a(miRanda|pictar), mmu-miR-130ac(Ta...     ...
# 1423281_at    mmu-let-7a(miRanda), mmu-let-7c(miRanda), mmu-...     ...
# 1453729_a_at  mmu-miR-134(miRanda), mmu-miR-139-5p(miRanda),...     ...
# 1418000_a_at  mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh
# 1418225_at       33.803515    5.814079
# 1422673_at       32.997538    5.744348
# 1423530_at       32.306493    5.683880
# 1453025_at       31.659045    5.626637
# 1460373_a_at     31.593667    5.620824
# 1449061_a_at     31.579367    5.619552
# 1452473_at       28.165968    5.307162
# 1448848_at       27.881632    5.280306
# 1417360_at       27.768936    5.269624
# 1450688_at       27.098664    5.205638
# 1428357_at       26.796515    5.176535
# 1439476_at       26.236049    5.122114
# 1418603_at       26.215092    5.120068
# 1423312_at       26.106963    5.109497
# 1426536_at       25.692268    5.068754
# ...                    ...         ...
# 1450970_at       26.716803    5.168830
# 1452184_at       27.033052    5.199332
# 1416781_at       27.126074    5.208270
# 1426710_at       27.729799    5.265909
# 1416243_a_at     27.857119    5.277984
# 1420611_at       27.906946    5.282703
# 1428379_at       28.605446    5.348406
# 1417653_at       28.767015    5.363489
# 1416112_at       30.202493    5.495679
# 1416971_at       30.702840    5.541014
# 1416277_a_at     30.837862    5.553185
# 1415970_at       31.125987    5.579067
# 1415819_a_at     31.328635    5.597199
# 1420871_at       31.925538    5.650269
# 1450088_a_at     32.278991    5.681460
# 1422576_at       33.451604    5.783736
# 1416829_at       35.646373    5.970458
# 1450875_at       37.622467    6.133716
# 1423652_at       38.461700    6.201750
# 1421813_a_at     42.383169    6.510236
# 1423281_at       42.649751    6.530678
# 1453729_a_at     46.561973    6.823633
# 1418000_a_at     46.682514    6.832460
# 1423409_a_at     48.650891    6.975019
# 1451961_a_at     52.036498    7.213633
# 1416269_at       53.158233    7.290969
# 1425467_a_at     70.110859    8.373223
# 1417502_at       71.759695    8.471109
# 1415906_at       88.509518    9.407950
# 1426313_at       96.486949    9.822777
#
# [19706 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM159292.CEL', 'GSM159293.CEL',
#        'GSM159294.CEL', 'avg-SCN', 'log_fold-SCN_vs_WB', 'fold-SCN_vs_WB',
#        'rawp-SCN_vs_WB', 'adjp-SCN_vs_WB', 'GSM189596.CEL', 'GSM189598.CEL',
#        'GSM189600.CEL', 'GSM189602.CEL', 'GSM189628.CEL', 'GSM189630.CEL',
#        'GSM189632.CEL', 'GSM189634.CEL', 'avg-WB', 'ANOVA-rawp', 'ANOVA-adjp',
#        'largest fold', '430AV2_Enrich', '430AV2_poolStDev', '430AV2_Cohens_d',
#        '430AV2_J', '430AV2_Hedges_g', '430AV2_Var_d', '430AV2_Var_g',
#        '430AV2_SEg'],
#       dtype='object')

# %% [markdown]
# ### Import key file from BioMart and index probesets to MGI gene symbols

# %%
dfX=pd.read_table('../BioMart_Ensmbl_index/mart_export72_430v2430Av2.txt',index_col=[3])
 
dfX.pop('Affy mouse430 2 probeset') # remove 430V2 probeset info (not needed for 430AV2 indexing)
dfX.head(5)
# Out:
#                               Ensembl Gene ID  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ENSMUSG00000039221
# NaN                        ENSMUSG00000095611
# 1417730_at                 ENSMUSG00000061731
# 1417730_at                 ENSMUSG00000061731
# NaN                        ENSMUSG00000061731
#
#                                                                  Description  \
# Affy mouse430a 2 probeset
# 1417126_a_at               ribosomal protein L22 like 1 [Source:MGI Symbo...
# NaN                        predicted gene 10597 [Source:MGI Symbol;Acc:MG...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# 1417730_at                 exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# NaN                        exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
#
#                           MGI symbol
# Affy mouse430a 2 probeset
# 1417126_a_at                 Rpl22l1
# NaN                          Gm10597
# 1417730_at                      Ext1
# 1417730_at                      Ext1
# NaN                             Ext1

# %%
df_Join = df.join(dfX, how='left', sort=True)
df_FINAL1 = df_Join.groupby('MGI symbol').mean()
df_FINAL1[df_FINAL1.index.duplicated()==True]   # checking that not duplicate entries exist in the dataframe
# Out:
# Empty DataFrame
# Columns: [GSM159292.CEL, GSM159293.CEL, GSM159294.CEL, avg-SCN, log_fold-SCN_vs_WB, fold-SCN_vs_WB, rawp-SCN_vs_WB, adjp-SCN_vs_WB, GSM189596.CEL, GSM189598.CEL, GSM189600.CEL, GSM189602.CEL, GSM189628.CEL, GSM189630.CEL, GSM189632.CEL, GSM189634.CEL, avg-WB, ANOVA-rawp, ANOVA-adjp, largest fold, 430AV2_Enrich, 430AV2_poolStDev, 430AV2_Cohens_d, 430AV2_J, 430AV2_Hedges_g, 430AV2_Var_d, 430AV2_Var_g, 430AV2_SEg]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# ### Columns from the list above can then easily be picked to produce files for use later. Examples below given:
#  #### df3 = average SCN and WB expression for the platform and the log-fold changes
#  #### df4 = Hedges g  values and associated variance for Meta-analysis (after indexing)

# %%
# df3 = df_FINAL1.loc[:,[u'avg-WB', u'avg-SCN', u'log_fold-SCN_vs_WB']]
# df3.columns =[prefix+'avg-WB', prefix+'avg-SCN', prefix+'log_fold-SCN_vs_WB']
# df3.to_csv('input_files/430AV2_SymbolExpression_forIndex.csv')

# %%
df4 = df_FINAL1.loc[:,[u'430AV2_Enrich',u'430AV2_Hedges_g', u'430AV2_Var_g', u'430AV2_SEg']]
df4.to_csv('input_files/430AV2_SymbolforIndexHedges.csv')

# %%
df4.head(10)  # check final ouput
# Out:
#                430AV2_Enrich  430AV2_Hedges_g  430AV2_Var_g  430AV2_SEg
# MGI symbol
# 0610005C13Rik       0.071840         0.392799      0.399175    0.631803
# 0610008F07Rik      -0.034139        -0.240750      0.394796    0.628328
# 0610009B22Rik       0.951853         5.058482      1.555264    1.247102
# 0610009D07Rik       0.011381         0.502373      0.895966    0.943195
# 0610009O20Rik      -0.916283        -5.843401      1.944222    1.394354
# 0610010K14Rik      -0.678961        -1.304555      0.469519    0.685215
# 0610012G03Rik      -0.344126        -1.029226      0.675020    0.798407
# 0610031J06Rik      -1.822928        -3.522490      0.956158    0.977834
# 0610037L13Rik       1.201002         4.925677      1.494993    1.222699
# 0610040J01Rik       0.074227         0.229441      0.394554    0.628136
