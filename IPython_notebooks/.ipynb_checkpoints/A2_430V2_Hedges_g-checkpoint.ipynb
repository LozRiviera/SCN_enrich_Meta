# %% [markdown]
# # Calculations of the Effect Size (ES) for each microarray study
#
# ###  Using Hedges' g value, an adjusted Cohen's d  value

# %% [markdown]
# $$  {Enrichment} = \bar{X_1}-\bar{X_2}$$
#
# where group1 is SCN Expression values and group2 are Whole Brain Expression values
# (SCN mean - WB mean) **(Logged values, so minus gives ratio)**

# %% [markdown]
# $$  {Pooled\ Standard\  Deviantion} = \sqrt\frac{(n_1-1)S_1^2 +(n_2-1)S_2^2}{(n_2 +n_2) -2}  $$

# %% [markdown]
# $$  {Cohen's\ d\ value} = \frac{Enrichment}{Pooled\ Standard\ Deviation} $$

# %% [markdown]
# $$  {Correction\ Factor (J\ Factor)} = 1- \frac{3}{4df-1} $$

# %% [markdown]
# $$  {Hedges'\ g\ value} = Cohen's\ d\ \text{x}\ J\ $$

# %% [markdown]
# $$  {Variance\ in\ d (V_d)} = \frac{n_1- +n_2}{n_1 n_2} + \frac{d^2}{2(n_1 +n_2)}  $$

# %% [markdown]
# $$  {Variance\ in\ g (V_g)} = J^2\  \text{x}\ V_d  $$

# %% [markdown]
# $$  {Standard\ Error\ in\ g (SE_g)} = \sqrt{V_g}  $$

# %% [markdown]
# ## Setup working environment and import data

# %%
import pandas as pd # Dataframes and good-glue
import numpy as np # numerical calculations

# %%
prefix = '430V2_'   # define a prefix to add to column names (making indexing easier later)

# %%
df=pd.read_table('../AltAnalyze_output/DATASET-430v2.txt', delimiter='\t',  index_col=0) #,nrows=500)  
df.head()
# Out:
#                 Symbol                         Definition          Ensembl_id  \
# Probesets
# 1427138_at     Ccdc88c  coiled-coil domain containing 88C  ENSMUSG00000021182
# 1448093_s_at    C77405          expressed sequence C77405                 NaN
# 1425600_a_at     Plcb1            phospholipase C, beta 1  ENSMUSG00000051177
# 1457168_at    AI225934        expressed sequence AI225934                 NaN
# 1450135_at        Fzd3    frizzled homolog 3 (Drosophila)  ENSMUSG00000007989
#
#              Entrez_id Unigene_id  \
# Probesets
# 1427138_at       68339        NaN
# 1448093_s_at     98108        NaN
# 1425600_a_at     18795        NaN
# 1457168_at       98884        NaN
# 1450135_at       14365        NaN
#
#                                                      GO-Process  \
# Probesets
# 1427138_at    protein destabilization // protein homooligome...
# 1448093_s_at                                                NaN
# 1425600_a_at  signal transduction // lipid catabolic process...
# 1457168_at                                                  NaN
# 1450135_at    neural tube closure // multicellular organisma...
#
#                                                     GO-Function  \
# Probesets
# 1427138_at    protein binding // PDZ domain binding // prote...
# 1448093_s_at                                                NaN
# 1425600_a_at  calcium ion binding // hydrolase activity // p...
# 1457168_at                                                  NaN
# 1450135_at    non-G-protein coupled 7TM receptor activity //...
#
#                                                    GO-Component  \
# Probesets
# 1427138_at                                   insoluble fraction
# 1448093_s_at                                                NaN
# 1425600_a_at                                          cytoplasm
# 1457168_at                                                  NaN
# 1450135_at    apical part of cell // integral to membrane //...
#
#                                                    Pathway_info  \
# Probesets
# 1427138_at                                                  NaN
# 1448093_s_at                                                NaN
# 1425600_a_at  Alzheimers Disease:WP2075(WikiPathways) // Che...
# 1457168_at                                                  NaN
# 1450135_at    ESC Pluripotency Pathways:WP339(WikiPathways) ...
#
#                                 Putative microRNA binding sites      ...       \
# Probesets                                                            ...
# 1427138_at    mmu-let-7c(RNAhybrid|miRanda), mmu-let-7d(RNAh...      ...
# 1448093_s_at                                                NaN      ...
# 1425600_a_at  mmu-miR-103(miRanda), mmu-miR-106ab(TargetScan...      ...
# 1457168_at                                                  NaN      ...
# 1450135_at    mmu-let-7(TargetScan), mmu-miR-105(TargetScan)...      ...
#
#              GSM414572.CEL GSM707557.CEL   avg-SCN  log_fold-SCN_vs_WB  \
# Probesets
# 1427138_at         6.67550       6.92059  6.787867           -0.198398
# 1448093_s_at       3.86671       3.79172  3.847880           -0.118651
# 1425600_a_at       7.31070       6.46585  7.021803           -0.064888
# 1457168_at         5.61380       5.44322  5.554147            0.029068
# 1450135_at         5.71821       5.29435  5.568443            0.364050
#
#               fold-SCN_vs_WB  rawp-SCN_vs_WB  adjp-SCN_vs_WB  ANOVA-rawp  \
# Probesets
# 1427138_at         -1.147423        0.047875        0.165634    0.030113
# 1448093_s_at       -1.085719        0.229335        0.439689    0.185091
# 1425600_a_at       -1.046004        0.916641        0.957518    0.923744
# 1457168_at          1.020353        0.756483        0.867974    0.725764
# 1450135_at          1.287034        0.008122        0.049437    0.008269
#
#               ANOVA-adjp  largest fold
# Probesets
# 1427138_at      0.124554      0.198398
# 1448093_s_at    0.387711      0.118651
# 1425600_a_at    0.961256      0.064888
# 1457168_at      0.847279      0.029068
# 1450135_at      0.052440      0.364050
#
# [5 rows x 37 columns]

# %%
# remove cross-hybridising probes
df =df[~df.index.str.contains('_x_|_s_')]    #   important reverse selector ~ 
df.shape
# Out:
# (40569, 37)

# %% [markdown]
# ## Look at column names and then setup filters for grouping columns into SCN and WB groups

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM252077.CEL', 'GSM252078.CEL',
#        'GSM252079.CEL', 'GSM511616.CEL', 'GSM511617.CEL', 'GSM511618.CEL',
#        'GSM511619.CEL', 'GSM511620.CEL', 'GSM511621.CEL', 'GSM511622.CEL',
#        'GSM511623.CEL', 'GSM511624.CEL', 'GSM511625.CEL', 'avg-WB',
#        'GSM414571.CEL', 'GSM414572.CEL', 'GSM707557.CEL', 'avg-SCN',
#        'log_fold-SCN_vs_WB', 'fold-SCN_vs_WB', 'rawp-SCN_vs_WB',
#        'adjp-SCN_vs_WB', 'ANOVA-rawp', 'ANOVA-adjp', 'largest fold'],
#       dtype='object')

# %%
# define regular expressions for filters 
scn_filt ='414|707'
wb_filt ='252|511'

# %%
df_scn=df.filter(regex= scn_filt)
df_scn.shape
# Out:
# (40569, 3)

# %%
df_wb=df.filter(regex= wb_filt)
df_wb.shape
# Out:
# (40569, 13)

# %% [markdown]
# ## Calculations

# %%
SCNcount = df.filter(regex=scn_filt).count(axis=1)

# %%
# Enrichment

df[prefix+'Enrich'] = df.filter(regex=scn_filt).mean(axis=1) - df.filter(regex=wb_filt).mean(axis=1)

# %%
df[prefix+'Enrich'].head()
# Out:
# Probesets
# 1427138_at     -0.198398
# 1425600_a_at   -0.064888
# 1457168_at      0.029068
# 1450135_at      0.364050
# 1424014_at     -0.200386
# Name: 430V2_Enrich, dtype: float64

# %%
# Pooled StDev
SCNcount = df.filter(regex=scn_filt).count(axis=1)
WBcount = df.filter(regex=wb_filt).count(axis=1)

StdevSCN = (SCNcount-1) * df.filter(regex=scn_filt).var(axis=1)
StdevWB = (WBcount-1) * df.filter(regex=wb_filt).var(axis=1)

df[prefix+'poolStDev'] = np.sqrt((StdevSCN+StdevWB)/(SCNcount+ WBcount-2))

# %%
#Cohen's d

df[prefix+'Cohens_d'] = df[prefix+'Enrich'] / df[prefix+'poolStDev']

# %%
df[prefix+'Cohens_d'] .head()
# Out:
# Probesets
# 1427138_at     -1.545517
# 1425600_a_at   -0.062423
# 1457168_at      0.229233
# 1450135_at      1.968094
# 1424014_at     -1.021103
# Name: 430V2_Cohens_d, dtype: float64

# %%
#J value (Correction factor)

df[prefix+'J'] = 1-(3/(4*(SCNcount+WBcount-1)))

# %%
#Hedge's g

df[prefix+'Hedges_g'] = df[prefix+'Cohens_d'] * df[prefix+'J']

# %%
#df[prefix+'J'].head()
df[prefix+'Hedges_g'] .head()
# Out:
# Probesets
# 1427138_at     -1.468241
# 1425600_a_at   -0.059302
# 1457168_at      0.217771
# 1450135_at      1.869689
# 1424014_at     -0.970048
# Name: 430V2_Hedges_g, dtype: float64

# %%
#Var_d
SCNcount = df.filter(regex=scn_filt).count(axis=1)
WBcount = df.filter(regex=wb_filt).count(axis=1)

Ftop1 = SCNcount + WBcount
Ftop2 = SCNcount * WBcount
Fbottom1 = np.square(df[prefix+'Cohens_d']) 
Fbottom2 =  2*(SCNcount + WBcount)


df[prefix+'Var_d'] = (Ftop1/Ftop2) + (Fbottom1 /Fbottom2)

# %%
#check
df[prefix+'Var_d'].head()
# Out:
# Probesets
# 1427138_at      0.484901
# 1425600_a_at    0.410378
# 1457168_at      0.411899
# 1450135_at      0.531300
# 1424014_at      0.442839
# Name: 430V2_Var_d, dtype: float64

# %%
df[prefix+'Var_g'] = df[prefix+'Var_d'] * np.square(df[prefix+'J'])

# %%
#SEg

df[prefix+'SEg'] = np.sqrt(df[prefix+'Var_g'])

# %%
df.sort_values(by=prefix+'Hedges_g', ascending=False, inplace=True)
df
# Out:
#                      Symbol  \
# Probesets
# 1418603_at           Avpr1a
# 1457265_at          Sfrs17b
# 1457396_at     LOC100045013
# 1460006_at            Zfhx3
# 1442809_at            Scn9a
# 1419408_at             Six6
# 1454731_at            Myo10
# 1423726_at             Vat1
# 1434073_at          Gprasp2
# 1438729_at             Sox1
# 1433577_at    A730017C20Rik
# 1417704_a_at        Arhgap6
# 1440564_at           Prokr2
# 1436484_at    C030019I05Rik
# 1433452_at    B630019K06Rik
# 1419428_a_at            Gaa
# 1450708_at             Scg2
# 1421899_a_at            Mr1
# 1434594_at           Dnahc1
# 1448188_at             Ucp2
# 1456333_a_at        Arhgap6
# 1417011_at             Sdc2
# 1415964_at             Scd1
# 1431812_a_at         Slc6a9
# 1423422_at             Asb4
# 1436913_at           Cdc14a
# 1434857_at    A230106D06Rik
# 1417217_at           Magel2
# 1430699_at           Gpr165
# 1433749_at            Gna13
# ...                     ...
# 1452196_a_at         Nckap1
# 1417129_a_at          Meis2
# 1455056_at             Lmo7
# 1441214_at            Exph5
# 1455463_at           Phyhip
# 1455436_at           Diras2
# 1452092_at    4631426J05Rik
# 1440286_at           Fbxl16
# 1418619_at            Icam5
# 1417829_a_at          Rab15
# 1459903_at           Sema7a
# 1455758_at            Prkcc
# 1455411_at          1913583
# 1455301_at            Wipf3
# 1452861_at    2010300C02Rik
# 1420388_at           Prss12
# 1460419_a_at          Prkcb
# 1434295_at          Rasgrp1
# 1435667_at            Rims1
# 1452227_at    2310045A20Rik
# 1424037_at            Itpka
# 1436275_at           Kcnip2
# 1428986_at          Slc17a7
# 1434653_at            Ptk2b
# 1436066_at            Kalrn
# 1424852_at            Mef2c
# 1455664_at          Rtn4rl1
# 1456487_at            Adcy1
# 1443287_at           Gm1337
# 1424248_at           Arpp21
#
#                                                      Definition  \
# Probesets
# 1418603_at                     arginine vasopressin receptor 1A
# 1457265_at            splicing factor, arginine/serine-rich 17b
# 1457396_at    similar to ventral anterior homeobox-containin...
# 1460006_at    zinc finger homeobox 3 [Source:MGI Symbol;Acc:...
# 1442809_at    sodium channel, voltage-gated, type IX, alpha ...
# 1419408_at    sine oculis-related homeobox 6 homolog (Drosop...
# 1454731_at          myosin X [Source:MGI Symbol;Acc:MGI:107716]
# 1423726_at    vesicle amine transport protein 1 homolog (T c...
# 1434073_at    G protein-coupled receptor associated sorting ...
# 1438729_at    SRY-box containing gene 1 [Source:MGI Symbol;A...
# 1433577_at    RIKEN cDNA A730017C20 gene [Source:MGI Symbol;...
# 1417704_a_at                    Rho GTPase activating protein 6
# 1440564_at    prokineticin receptor 2 [Source:MGI Symbol;Acc...
# 1436484_at    fibronectin type III domain containing 9 [Sour...
# 1433452_at    RIKEN cDNA B630019K06 gene [Source:MGI Symbol;...
# 1419428_a_at                           glucosidase, alpha, acid
# 1450708_at                                     secretogranin II
# 1421899_a_at  major histocompatibility complex, class I-related
# 1434594_at    dynein, axonemal, heavy chain 1 [Source:MGI Sy...
# 1448188_at    uncoupling protein 2 (mitochondrial, proton ca...
# 1456333_a_at                    Rho GTPase activating protein 6
# 1417011_at                                           syndecan 2
# 1415964_at                     stearoyl-Coenzyme A desaturase 1
# 1431812_a_at  solute carrier family 6 (neurotransmitter tran...
# 1423422_at             ankyrin repeat and SOCS box-containing 4
# 1436913_at    CDC14 cell division cycle 14A [Source:MGI Symb...
# 1434857_at    zinc finger protein 783 [Source:MGI Symbol;Acc...
# 1417217_at                        melanoma antigen, family L, 2
# 1430699_at    G protein-coupled receptor 165 [Source:MGI Sym...
# 1433749_at    guanine nucleotide binding protein, alpha 13 [...
# ...                                                         ...
# 1452196_a_at                           NCK-associated protein 1
# 1417129_a_at  myeloid ecotropic viral integration site-relat...
# 1455056_at                                    LIM domain only 7
# 1441214_at                                          exophilin 5
# 1455463_at    phytanoyl-CoA hydroxylase interacting protein ...
# 1455436_at    DIRAS family, GTP-binding RAS-like 2 [Source:M...
# 1452092_at    carbohydrate (N-acetylgalactosamine 4-sulfate ...
# 1440286_at    F-box and leucine-rich repeat protein 16 [Sour...
# 1418619_at     intercellular adhesion molecule 5, telencephalin
# 1417829_a_at                  RAB15, member RAS oncogene family
# 1459903_at    sema domain, immunoglobulin domain (Ig), and G...
# 1455758_at                              protein kinase C, gamma
# 1455411_at                                                  NaN
# 1455301_at    WAS/WASL interacting protein family, member 3 ...
# 1452861_at    RIKEN cDNA 2010300C02 gene [Source:MGI Symbol;...
# 1420388_at         protease, serine, 12 neurotrypsin (motopsin)
# 1460419_a_at                           protein kinase C, beta 1
# 1434295_at    RAS guanyl releasing protein 1 [Source:MGI Sym...
# 1435667_at    regulating synaptic membrane exocytosis 1 [Sou...
# 1452227_at       sel-1 suppressor of lin-12-like 3 (C. elegans)
# 1424037_at              inositol 1,4,5-trisphosphate 3-kinase A
# 1436275_at    Kv channel-interacting protein 2 [Source:MGI S...
# 1428986_at    solute carrier family 17 (sodium-dependent ino...
# 1434653_at                  PTK2 protein tyrosine kinase 2 beta
# 1436066_at                               kalirin, RhoGEF kinase
# 1424852_at                           myocyte enhancer factor 2C
# 1455664_at    reticulon 4 receptor-like 1 [Source:MGI Symbol...
# 1456487_at    adenylate cyclase 1 [Source:MGI Symbol;Acc:MGI...
# 1443287_at    ankyrin repeat domain 63 [Source:MGI Symbol;Ac...
# 1424248_at              cyclic AMP-regulated phosphoprotein, 21
#
#                                          Ensembl_id  Entrez_id Unigene_id  \
# Probesets
# 1418603_at                       ENSMUSG00000020123      54140        NaN
# 1457265_at                       ENSMUSG00000059708     338351        NaN
# 1457396_at                                      NaN  100045013        NaN
# 1460006_at                       ENSMUSG00000038872      11906        NaN
# 1442809_at                       ENSMUSG00000075316      20274        NaN
# 1419408_at                       ENSMUSG00000021099      20476        NaN
# 1454731_at                       ENSMUSG00000022272      17909        NaN
# 1423726_at                       ENSMUSG00000034993      26949        NaN
# 1434073_at                       ENSMUSG00000072966     245607        NaN
# 1438729_at                       ENSMUSG00000096014      20664        NaN
# 1433577_at                       ENSMUSG00000050875     225583        NaN
# 1417704_a_at                     ENSMUSG00000031355      11856        NaN
# 1440564_at                       ENSMUSG00000050558     246313        NaN
# 1436484_at                       ENSMUSG00000048721     320116        NaN
# 1433452_at                       ENSMUSG00000052364     102941        NaN
# 1419428_a_at                     ENSMUSG00000025579      14387        NaN
# 1450708_at                       ENSMUSG00000050711      20254        NaN
# 1421899_a_at                     ENSMUSG00000026471      15064        NaN
# 1434594_at                       ENSMUSG00000019027     110084        NaN
# 1448188_at                       ENSMUSG00000033685      22228        NaN
# 1456333_a_at                     ENSMUSG00000031355      11856        NaN
# 1417011_at                       ENSMUSG00000022261      15529        NaN
# 1415964_at                       ENSMUSG00000037071      20249        NaN
# 1431812_a_at                     ENSMUSG00000028542      14664        NaN
# 1423422_at                       ENSMUSG00000042607      65255        NaN
# 1436913_at                       ENSMUSG00000033502     229776        NaN
# 1434857_at    ENSMUSG00000072653|ENSMUSG00000079573     232785        NaN
# 1417217_at                       ENSMUSG00000056972      27385        NaN
# 1430699_at                       ENSMUSG00000031210      76206        NaN
# 1433749_at                       ENSMUSG00000020611      14674        NaN
# ...                                             ...        ...        ...
# 1452196_a_at                     ENSMUSG00000027002      50884        NaN
# 1417129_a_at                     ENSMUSG00000027210      17536        NaN
# 1455056_at                       ENSMUSG00000033060     380928        NaN
# 1441214_at                                      NaN     320051  Mm.390155
# 1455463_at                       ENSMUSG00000003469     105653        NaN
# 1455436_at                       ENSMUSG00000047842      68203        NaN
# 1452092_at                       ENSMUSG00000030930      77590        NaN
# 1440286_at                       ENSMUSG00000025738     214931        NaN
# 1418619_at                       ENSMUSG00000032174      15898        NaN
# 1417829_a_at                     ENSMUSG00000021062     104886        NaN
# 1459903_at                       ENSMUSG00000038264      20361        NaN
# 1455758_at                       ENSMUSG00000078816      18752        NaN
# 1455411_at                                      NaN        NaN  Mm.458655
# 1455301_at                       ENSMUSG00000086040     330319        NaN
# 1452861_at                       ENSMUSG00000026090      72097        NaN
# 1420388_at                       ENSMUSG00000027978      19142        NaN
# 1460419_a_at                     ENSMUSG00000052889      18751        NaN
# 1434295_at                       ENSMUSG00000027347      19419        NaN
# 1435667_at                       ENSMUSG00000041670     116837        NaN
# 1452227_at                       ENSMUSG00000029189     231238        NaN
# 1424037_at                       ENSMUSG00000027296     228550        NaN
# 1436275_at                       ENSMUSG00000025221      80906        NaN
# 1428986_at                       ENSMUSG00000070570      72961        NaN
# 1434653_at                       ENSMUSG00000059456      19229        NaN
# 1436066_at                       ENSMUSG00000061751     545156        NaN
# 1424852_at                       ENSMUSG00000005583      17260        NaN
# 1455664_at                       ENSMUSG00000045287     237847        NaN
# 1456487_at                       ENSMUSG00000020431     432530        NaN
# 1443287_at                       ENSMUSG00000078137     383787        NaN
# 1424248_at                       ENSMUSG00000032503      74100        NaN
#
#                                                      GO-Process  \
# Probesets
# 1418603_at    G-protein coupled receptor protein signaling p...
# 1457265_at                      RNA splicing // mRNA processing
# 1457396_at                                                  NaN
# 1460006_at    transcription // negative regulation of transc...
# 1442809_at    sodium ion transport // inflammatory response ...
# 1419408_at    multicellular organismal development // regula...
# 1454731_at                                  signal transduction
# 1423726_at             metabolic process // oxidation reduction
# 1434073_at                                                  NaN
# 1438729_at    forebrain neuron development // lens morphogen...
# 1433577_at                                                  NaN
# 1417704_a_at  regulation of GTPase activity // signal transd...
# 1440564_at    signal transduction // G-protein coupled recep...
# 1436484_at                                                  NaN
# 1433452_at                                                  NaN
# 1419428_a_at  tongue morphogenesis // glycogen metabolic pro...
# 1450708_at    cell motion // eosinophil chemotaxis // negati...
# 1421899_a_at  antigen processing and presentation of peptide...
# 1434594_at                           microtubule-based movement
# 1448188_at    response to superoxide // transport // mitocho...
# 1456333_a_at  regulation of GTPase activity // signal transd...
# 1417011_at                                                  NaN
# 1415964_at    oxidation reduction // lipid biosynthetic proc...
# 1431812_a_at  glycine transport // transport // amino acid t...
# 1423422_at    ubiquitin-dependent protein catabolic process ...
# 1436913_at    cell division // protein amino acid dephosphor...
# 1434857_at                                                  NaN
# 1417217_at                          regulation of transcription
# 1430699_at    G-protein coupled receptor protein signaling p...
# 1433749_at    G-protein coupled receptor protein signaling p...
# ...                                                         ...
# 1452196_a_at  embryonic foregut morphogenesis // neural tube...
# 1417129_a_at  eye development // regulation of transcription...
# 1455056_at                                   cell-cell adhesion
# 1441214_at                      intracellular protein transport
# 1455463_at                                                  NaN
# 1455436_at            small GTPase mediated signal transduction
# 1452092_at                          hexose biosynthetic process
# 1440286_at        ubiquitin-dependent protein catabolic process
# 1418619_at    cell adhesion // phagocytosis // cell-cell adh...
# 1417829_a_at  small GTPase mediated signal transduction // r...
# 1459903_at    multicellular organismal development // nervou...
# 1455758_at    learning or memory // protein amino acid phosp...
# 1455411_at                                                  NaN
# 1455301_at    spermatogenesis // multicellular organismal de...
# 1452861_at                                                  NaN
# 1420388_at                                          proteolysis
# 1460419_a_at  protein amino acid phosphorylation // calcium ...
# 1434295_at    intracellular signaling cascade // regulation ...
# 1435667_at    neurotransmitter transport // protein complex ...
# 1452227_at                                                  NaN
# 1424037_at                           inositol metabolic process
# 1436275_at    ion transport // potassium ion transport // tr...
# 1428986_at    response to stimulus // neurotransmitter trans...
# 1434653_at    protein amino acid phosphorylation // signal c...
# 1436066_at    protein amino acid phosphorylation // regulati...
# 1424852_at    positive regulation of transcription // regula...
# 1455664_at                                    axon regeneration
# 1456487_at    cAMP biosynthetic process // activation of ade...
# 1443287_at                                                  NaN
# 1424248_at                                                  NaN
#
#                                                     GO-Function  \
# Probesets
# 1418603_at    peptide hormone binding // vasopressin recepto...
# 1457265_at                  nucleic acid binding // RNA binding
# 1457396_at                                                  NaN
# 1460006_at    nucleic acid binding // transcription factor a...
# 1442809_at    voltage-gated sodium channel activity // sodiu...
# 1419408_at    transcription factor activity // DNA binding /...
# 1454731_at    motor activity // nucleotide binding // bindin...
# 1423726_at    catalytic activity // binding // oxidoreductas...
# 1434073_at    protein binding // G-protein-coupled receptor ...
# 1438729_at         DNA binding // sequence-specific DNA binding
# 1433577_at                                                  NaN
# 1417704_a_at  Rho GTPase activator activity // GTPase activa...
# 1440564_at    receptor activity // signal transducer activit...
# 1436484_at                                                  NaN
# 1433452_at                                                  NaN
# 1419428_a_at  hydrolase activity // hydrolase activity, acti...
# 1450708_at    calcium ion binding // cytokine activity // ch...
# 1421899_a_at                                                NaN
# 1434594_at    microtubule motor activity // ATPase activity ...
# 1448188_at                      transporter activity // binding
# 1456333_a_at  Rho GTPase activator activity // GTPase activa...
# 1417011_at      protein binding // cytoskeletal protein binding
# 1415964_at    stearoyl-CoA 9-desaturase activity // oxidored...
# 1431812_a_at  sodium:amino acid symporter activity // neurot...
# 1423422_at                                                  NaN
# 1436913_at    protein tyrosine phosphatase activity // hydro...
# 1434857_at                                     zinc ion binding
# 1417217_at                                      protein binding
# 1430699_at                                    receptor activity
# 1433749_at    protein binding // GTPase activity // signal t...
# ...                                                         ...
# 1452196_a_at                                                NaN
# 1417129_a_at  transcription factor activity // DNA binding /...
# 1455056_at    protein binding // actinin binding // zinc ion...
# 1441214_at                Rab GTPase binding // protein binding
# 1455463_at                                      protein binding
# 1455436_at                    nucleotide binding // GTP binding
# 1452092_at    3'-phosphoadenosine 5'-phosphosulfate binding ...
# 1440286_at                                      protein binding
# 1418619_at                                      protein binding
# 1417829_a_at  protein binding // transcription factor bindin...
# 1459903_at                                    receptor activity
# 1455758_at    calcium ion binding // diacylglycerol binding ...
# 1455411_at                                                  NaN
# 1455301_at                                        actin binding
# 1452861_at                                                  NaN
# 1420388_at    scavenger receptor activity // serine-type end...
# 1460419_a_at  calcium ion binding // diacylglycerol binding ...
# 1434295_at    calcium ion binding // guanyl-nucleotide excha...
# 1435667_at    Rab GTPase binding // protein binding // metal...
# 1452227_at                                              binding
# 1424037_at    nucleotide binding // transferase activity // ...
# 1436275_at    calcium ion binding // potassium channel activ...
# 1428986_at    transporter activity // symporter activity // ...
# 1434653_at    protein binding // non-membrane spanning prote...
# 1436066_at    magnesium ion binding // transferase activity ...
# 1424852_at    transcription factor activity // DNA binding /...
# 1455664_at                 protein binding // receptor activity
# 1456487_at    magnesium ion binding // lyase activity // ade...
# 1443287_at                                                  NaN
# 1424248_at                                 nucleic acid binding
#
#                                                    GO-Component  \
# Probesets
# 1418603_at    plasma membrane // integral to membrane // mem...
# 1457265_at              spliceosome // nucleus // nuclear speck
# 1457396_at                                                  NaN
# 1460006_at    mitochondrion // transcription factor complex ...
# 1442809_at    voltage-gated sodium channel complex // integr...
# 1419408_at                                              nucleus
# 1454731_at                       cytoskeleton // myosin complex
# 1423726_at                                                  NaN
# 1434073_at                                 cytoplasm // nucleus
# 1438729_at                                              nucleus
# 1433577_at                     integral to membrane // membrane
# 1417704_a_at   cytoplasm // intracellular // actin cytoskeleton
# 1440564_at    plasma membrane // integral to membrane // mem...
# 1436484_at                     integral to membrane // membrane
# 1433452_at                                                  NaN
# 1419428_a_at                                           lysosome
# 1450708_at          extracellular region // extracellular space
# 1421899_a_at  endoplasmic reticulum // MHC class I protein c...
# 1434594_at            dynein complex // axonemal dynein complex
# 1448188_at    mitochondrion // mitochondrial inner membrane ...
# 1456333_a_at   cytoplasm // intracellular // actin cytoskeleton
# 1417011_at                     integral to membrane // membrane
# 1415964_at    endoplasmic reticulum membrane // endoplasmic ...
# 1431812_a_at  integral to plasma membrane // integral to mem...
# 1423422_at                                                  NaN
# 1436913_at                     spindle // nucleus // centrosome
# 1434857_at                                        intracellular
# 1417217_at                                                  NaN
# 1430699_at                                 integral to membrane
# 1433749_at    heterotrimeric G-protein complex // melanosome...
# ...                                                         ...
# 1452196_a_at  cytoplasm // integral to membrane // membrane ...
# 1417129_a_at                                            nucleus
# 1455056_at    apical plasma membrane // cell-cell adherens j...
# 1441214_at                                                  NaN
# 1455463_at                                                  NaN
# 1455436_at         intracellular // plasma membrane // membrane
# 1452092_at    Golgi membrane // Golgi apparatus // integral ...
# 1440286_at                                                  NaN
# 1418619_at    plasma membrane // integral to membrane // mem...
# 1417829_a_at       intracellular // plasma membrane // membrane
# 1459903_at    anchored to membrane // plasma membrane // mem...
# 1455758_at    cytosol // cytoplasm // synaptosome // nucleus...
# 1455411_at                                                  NaN
# 1455301_at                                            cytoplasm
# 1452861_at                                                  NaN
# 1420388_at                     extracellular region // membrane
# 1460419_a_at                   cytoplasm // nucleus // membrane
# 1434295_at    endoplasmic reticulum membrane // Golgi appara...
# 1435667_at    synapse // membrane // cell junction // plasma...
# 1452227_at                     integral to membrane // membrane
# 1424037_at                                                  NaN
# 1436275_at                          plasma membrane // membrane
# 1428986_at    synaptosome // synapse // cytoplasmic vesicle ...
# 1434653_at    cytoplasm // cytoskeleton // focal adhesion //...
# 1436066_at           cytoplasm // cytoskeleton // intracellular
# 1424852_at                                              nucleus
# 1455664_at    anchored to membrane // plasma membrane // anc...
# 1456487_at    plasma membrane // integral to membrane // mem...
# 1443287_at                                                  NaN
# 1424248_at                                            cytoplasm
#
#                                                    Pathway_info  \
# Probesets
# 1418603_at    GPCRs, Class A Rhodopsin-like:WP189(WikiPathwa...
# 1457265_at                  mRNA processing:WP310(WikiPathways)
# 1457396_at                                                  NaN
# 1460006_at                                                  NaN
# 1442809_at                                                  NaN
# 1419408_at                                                  NaN
# 1454731_at                                                  NaN
# 1423726_at                                                  NaN
# 1434073_at                                                  NaN
# 1438729_at    Wnt Signaling Pathway NetPath:WP539(WikiPathways)
# 1433577_at                                                  NaN
# 1417704_a_at                                                NaN
# 1440564_at               Non-odorant GPCRs:WP1396(WikiPathways)
# 1436484_at                                                  NaN
# 1433452_at                                                  NaN
# 1419428_a_at                                                NaN
# 1450708_at                                                  NaN
# 1421899_a_at                                                NaN
# 1434594_at                                                  NaN
# 1448188_at    Electron Transport Chain:WP295(WikiPathways) /...
# 1456333_a_at                                                NaN
# 1417011_at                                                  NaN
# 1415964_at    PPAR signaling pathway:KEGG-mmu03320:WP2316(Wi...
# 1431812_a_at                                                NaN
# 1423422_at                                                  NaN
# 1436913_at                                                  NaN
# 1434857_at                                                  NaN
# 1417217_at                                                  NaN
# 1430699_at    Orphan GPCRs:WP1398(WikiPathways) // GPCRs, Ot...
# 1433749_at    GenMAPP-G_Protein_Signaling // G13 Signaling P...
# ...                                                         ...
# 1452196_a_at  GenMAPP-Circadian_Exercise // Diurnally Regula...
# 1417129_a_at                                                NaN
# 1455056_at                                                  NaN
# 1441214_at                                                  NaN
# 1455463_at                                                  NaN
# 1455436_at                                                  NaN
# 1452092_at                                                  NaN
# 1440286_at                                                  NaN
# 1418619_at    XPodNet - protein-protein interactions in the ...
# 1417829_a_at                                                NaN
# 1459903_at                                                  NaN
# 1455758_at    PluriNetWork:WP1763(WikiPathways) // GenMAPP-G...
# 1455411_at                                                  NaN
# 1455301_at                                                  NaN
# 1452861_at                                                  NaN
# 1420388_at                                                  NaN
# 1460419_a_at  Insulin Signaling:WP65(WikiPathways) // IL-3 S...
# 1434295_at           MAPK signaling pathway:WP493(WikiPathways)
# 1435667_at                                                  NaN
# 1452227_at                                                  NaN
# 1424037_at                                                  NaN
# 1436275_at                                                  NaN
# 1428986_at                                                  NaN
# 1434653_at    IL-6 signaling Pathway:WP387(WikiPathways) // ...
# 1436066_at                                                  NaN
# 1424852_at    PluriNetWork:WP1763(WikiPathways) // MAPK sign...
# 1455664_at                                                  NaN
# 1456487_at    GenMAPP-G_Protein_Signaling // Hypothetical Ne...
# 1443287_at                                                  NaN
# 1424248_at                                                  NaN
#
#                                 Putative microRNA binding sites    ...      \
# Probesets                                                          ...
# 1418603_at    mmu-let-7d(miRanda), mmu-miR-10a(miRanda), mmu...    ...
# 1457265_at    mmu-miR-1192(miRanda), mmu-miR-124(miRanda), m...    ...
# 1457396_at                                                  NaN    ...
# 1460006_at    mmu-miR-101(TargetScan), mmu-miR-101ab(TargetS...    ...
# 1442809_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...    ...
# 1419408_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...    ...
# 1454731_at    mmu-let-7g(RNAhybrid|miRanda), mmu-miR-101a(RN...    ...
# 1423726_at    mmu-let-7a(miRanda), mmu-let-7f(miRanda), mmu-...    ...
# 1434073_at    mmu-miR-1271(TargetScan), mmu-miR-138(miRanda)...    ...
# 1438729_at    mmu-miR-139(pictar), mmu-miR-139-5p(TargetScan...    ...
# 1433577_at    mmu-miR-103(miRanda), mmu-miR-107(miRanda), mm...    ...
# 1417704_a_at  mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...    ...
# 1440564_at    mmu-miR-129-5p(miRanda), mmu-miR-135a(miRanda)...    ...
# 1436484_at    mmu-let-7i(miRanda), mmu-miR-125a-3p(miRanda),...    ...
# 1433452_at    mmu-miR-1(miRanda), mmu-miR-101a(miRanda), mmu...    ...
# 1419428_a_at  mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...    ...
# 1450708_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...    ...
# 1421899_a_at  mmu-let-7e(miRanda), mmu-miR-106a(miRanda), mm...    ...
# 1434594_at    mmu-miR-143(miRanda), mmu-miR-146a(miRanda), m...    ...
# 1448188_at    mmu-miR-132(miRanda), mmu-miR-203(miRanda), mm...    ...
# 1456333_a_at  mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...    ...
# 1417011_at    mmu-let-7d(pictar), mmu-miR-106a(miRanda), mmu...    ...
# 1415964_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...    ...
# 1431812_a_at  mmu-let-7a(RNAhybrid|miRanda), mmu-let-7i(RNAh...    ...
# 1423422_at    mmu-let-7e(miRanda), mmu-let-7f(miRanda), mmu-...    ...
# 1436913_at    mmu-let-7c(miRanda), mmu-miR-1(RNAhybrid|Targe...    ...
# 1434857_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...    ...
# 1417217_at    mmu-miR-101a(miRanda), mmu-miR-101b(miRanda), ...    ...
# 1430699_at    mmu-let-7b(miRanda), mmu-let-7e(miRanda), mmu-...    ...
# 1433749_at    mmu-let-7b(miRanda), mmu-miR-1192(miRanda), mm...    ...
# ...                                                         ...    ...
# 1452196_a_at  mmu-let-7b(RNAhybrid|miRanda), mmu-let-7d(RNAh...    ...
# 1417129_a_at  mmu-let-7(TargetScan), mmu-let-7a(miRanda|pict...    ...
# 1455056_at    mmu-let-7f(RNAhybrid|miRanda), mmu-miR-1(miRan...    ...
# 1441214_at                                                  NaN    ...
# 1455463_at    mmu-miR-1(miRanda), mmu-miR-125a(pictar), mmu-...    ...
# 1455436_at    mmu-miR-106a(miRanda), mmu-miR-106b(miRanda), ...    ...
# 1452092_at    mmu-miR-127(miRanda), mmu-miR-136(miRanda), mm...    ...
# 1440286_at    mmu-let-7g(RNAhybrid|miRanda), mmu-miR-101a(RN...    ...
# 1418619_at    mmu-miR-1(miRanda), mmu-miR-1192(miRanda), mmu...    ...
# 1417829_a_at  mmu-let-7(TargetScan), mmu-let-7a(miRanda|pict...    ...
# 1459903_at    mmu-let-7e(miRanda), mmu-let-7g(miRanda), mmu-...    ...
# 1455758_at    mmu-miR-324-5p(TargetScan|pictar), mmu-miR-338...    ...
# 1455411_at                                                  NaN    ...
# 1455301_at    mmu-miR-1(miRanda), mmu-miR-103(miRanda), mmu-...    ...
# 1452861_at    mmu-miR-129-5p(miRanda), mmu-miR-132(miRanda),...    ...
# 1420388_at    mmu-miR-138(miRanda), mmu-miR-22(RNAhybrid|miR...    ...
# 1460419_a_at  mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...    ...
# 1434295_at    mmu-let-7(TargetScan), mmu-let-7a(miRanda|pict...    ...
# 1435667_at    mmu-miR-1(RNAhybrid), mmu-miR-103(RNAhybrid|mi...    ...
# 1452227_at    mmu-let-7b(miRanda), mmu-miR-101a(RNAhybrid|mi...    ...
# 1424037_at    mmu-miR-19a(miRanda), mmu-miR-19b(miRanda), mm...    ...
# 1436275_at    mmu-miR-103a(TargetScan), mmu-miR-107(TargetSc...    ...
# 1428986_at    mmu-miR-106a(miRanda), mmu-miR-106ab(TargetSca...    ...
# 1434653_at    mmu-let-7d(RNAhybrid|miRanda), mmu-let-7e(RNAh...    ...
# 1436066_at    mmu-let-7a(RNAhybrid|miRanda), mmu-let-7b(RNAh...    ...
# 1424852_at    mmu-let-7(TargetScan), mmu-let-7a(RNAhybrid|mi...    ...
# 1455664_at    mmu-miR-106a(miRanda), mmu-miR-106b(miRanda), ...    ...
# 1456487_at    mmu-miR-100(TargetScan|pictar), mmu-miR-124(Ta...    ...
# 1443287_at    mmu-miR-139-5p(miRanda), mmu-miR-143(miRanda),...    ...
# 1424248_at    mmu-let-7a(miRanda), mmu-let-7b(miRanda), mmu-...    ...
#
#                 ANOVA-adjp largest fold  430V2_Enrich  430V2_poolStDev  \
# Probesets
# 1418603_at    8.849224e-10     2.410178      2.410178         0.131454
# 1457265_at    1.472018e-09     1.660074      1.660074         0.097228
# 1457396_at    2.525826e-09     2.974166      2.974166         0.185510
# 1460006_at    2.895053e-09     3.627305      3.627305         0.230275
# 1442809_at    6.753430e-09     2.650461      2.650461         0.182478
# 1419408_at    7.033843e-09     3.926071      3.926071         0.274588
# 1454731_at    4.070012e-08     1.318415      1.318415         0.108384
# 1423726_at    4.483654e-08     3.317615      3.317615         0.277102
# 1434073_at    6.232190e-08     1.675347      1.675347         0.144421
# 1438729_at    6.700320e-08     2.585644      2.585644         0.225324
# 1433577_at    7.231180e-08     2.175697      2.175697         0.191953
# 1417704_a_at  8.472750e-08     2.622788      2.622788         0.235115
# 1440564_at    8.650192e-08     3.433871      3.433871         0.308913
# 1436484_at    1.045767e-07     1.754486      1.754486         0.160994
# 1433452_at    1.369164e-07     2.628699      2.628699         0.247601
# 1419428_a_at  1.774828e-07     2.065588      2.065588         0.200012
# 1450708_at    1.871165e-07     1.886715      1.886715         0.184604
# 1421899_a_at  2.764861e-07     1.129597      1.129597         0.114868
# 1434594_at    2.933817e-07     1.959830      1.959830         0.200676
# 1448188_at    2.941668e-07     1.865472      1.865472         0.191280
# 1456333_a_at  3.112488e-07     2.379400      2.379400         0.245931
# 1417011_at    3.112488e-07     1.524928      1.524928         0.157705
# 1415964_at    3.237928e-07     1.708615      1.708615         0.177859
# 1431812_a_at  3.787390e-07     1.589179      1.589179         0.168636
# 1423422_at    3.787390e-07     1.804691      1.804691         0.191776
# 1436913_at    3.787390e-07     2.485421      2.485421         0.264183
# 1434857_at    3.804535e-07     1.699081      1.699081         0.180832
# 1417217_at    4.824201e-07     3.561849      3.561849         0.388746
# 1430699_at    5.100385e-07     2.093645      2.093645         0.229668
# 1433749_at    5.631357e-07     0.853880      0.853880         0.094535
# ...                    ...          ...           ...              ...
# 1452196_a_at  1.871165e-07     0.542125     -0.542125         0.052970
# 1417129_a_at  1.844323e-07     3.926975     -3.926975         0.382172
# 1455056_at    1.774828e-07     2.813985     -2.813985         0.272662
# 1441214_at    1.756828e-07     3.859551     -3.859551         0.372544
# 1455463_at    1.551811e-07     1.657168     -1.657168         0.158228
# 1455436_at    1.369164e-07     1.991378     -1.991378         0.188061
# 1452092_at    1.369164e-07     1.453496     -1.453496         0.137209
# 1440286_at    1.327978e-07     0.926682     -0.926682         0.086874
# 1418619_at    1.121402e-07     2.519766     -2.519766         0.232845
# 1417829_a_at  9.513541e-08     1.118372     -1.118372         0.101714
# 1459903_at    9.513541e-08     2.070007     -2.070007         0.187989
# 1455758_at    8.287267e-08     2.513491     -2.513491         0.224488
# 1455411_at    7.113064e-08     1.053030     -1.053030         0.092591
# 1455301_at    7.113064e-08     2.468583     -2.468583         0.216745
# 1452861_at    6.455834e-08     2.522660     -2.522660         0.218712
# 1420388_at    6.232190e-08     1.427618     -1.427618         0.123149
# 1460419_a_at  4.876350e-08     1.779392     -1.779392         0.149954
# 1434295_at    4.366176e-08     2.546169     -2.546169         0.211359
# 1435667_at    3.795871e-08     1.772705     -1.772705         0.144524
# 1452227_at    3.284735e-08     1.898645     -1.898645         0.152642
# 1424037_at    3.256480e-08     3.361289     -3.361289         0.269132
# 1436275_at    2.295135e-08     1.386169     -1.386169         0.107770
# 1428986_at    2.206013e-08     4.016557     -4.016557         0.310187
# 1434653_at    2.093803e-08     2.877463     -2.877463         0.220484
# 1436066_at    8.366479e-09     4.274202     -4.274202         0.304863
# 1424852_at    7.033843e-09     3.664192     -3.664192         0.256903
# 1455664_at    2.514243e-09     2.317872     -2.317872         0.143290
# 1456487_at    8.849224e-10     3.366366     -3.366366         0.186401
# 1443287_at    2.343266e-10     2.788689     -2.788689         0.135144
# 1424248_at    1.456285e-10     3.489935     -3.489935         0.158692
#
#               430V2_Cohens_d  430V2_J  430V2_Hedges_g  430V2_Var_d  \
# Probesets
# 1418603_at         18.334705     0.95       17.417969    10.915300
# 1457265_at         17.074045     0.95       16.220343     9.520351
# 1457396_at         16.032354     0.95       15.230736     8.442643
# 1460006_at         15.752039     0.95       14.964437     8.164217
# 1442809_at         14.524863     0.95       13.798620     7.003120
# 1419408_at         14.298066     0.95       13.583163     6.798841
# 1454731_at         12.164345     0.95       11.556128     5.034360
# 1423726_at         11.972554     0.95       11.373927     4.889696
# 1434073_at         11.600451     0.95       11.020429     4.615584
# 1438729_at         11.475223     0.95       10.901462     4.525280
# 1433577_at         11.334530     0.95       10.767804     4.424993
# 1417704_a_at       11.155326     0.95       10.597560     4.299047
# 1440564_at         11.115996     0.95       10.560196     4.271674
# 1436484_at         10.897813     0.95       10.352923     4.121579
# 1433452_at         10.616659     0.95       10.085826     3.932552
# 1419428_a_at       10.327317     0.95        9.810952     3.743178
# 1450708_at         10.220325     0.95        9.709309     3.674476
# 1421899_a_at        9.833838     0.95        9.342147     3.432268
# 1434594_at          9.766154     0.95        9.277847     3.390812
# 1448188_at          9.752590     0.95        9.264960     3.382538
# 1456333_a_at        9.675060     0.95        9.191307     3.335469
# 1417011_at          9.669522     0.95        9.186046     3.332121
# 1415964_at          9.606572     0.95        9.126243     3.294201
# 1431812_a_at        9.423718     0.95        8.952532     3.185458
# 1423422_at          9.410388     0.95        8.939868     3.177613
# 1436913_at          9.407957     0.95        8.937559     3.176183
# 1434857_at          9.395891     0.95        8.926096     3.169093
# 1417217_at          9.162395     0.95        8.704275     3.033678
# 1430699_at          9.115957     0.95        8.660159     3.007152
# 1433749_at          9.032412     0.95        8.580792     2.959771
# ...                      ...      ...             ...          ...
# 1452196_a_at      -10.234478     0.95       -9.722754     3.683523
# 1417129_a_at      -10.275420     0.95       -9.761649     3.709765
# 1455056_at        -10.320406     0.95       -9.804386     3.738718
# 1441214_at        -10.359977     0.95       -9.841978     3.764292
# 1455463_at        -10.473311     0.95       -9.949646     3.838077
# 1455436_at        -10.589027     0.95      -10.059576     3.914241
# 1452092_at        -10.593318     0.95      -10.063652     3.917081
# 1440286_at        -10.666947     0.95      -10.133599     3.965999
# 1418619_at        -10.821638     0.95      -10.280556     4.069876
# 1417829_a_at      -10.995283     0.95      -10.445519     4.188264
# 1459903_at        -11.011321     0.95      -10.460755     4.199293
# 1455758_at        -11.196569     0.95      -10.636740     4.327855
# 1455411_at        -11.372931     0.95      -10.804284     4.452243
# 1455301_at        -11.389344     0.95      -10.819877     4.463918
# 1452861_at        -11.534157     0.95      -10.957450     4.567656
# 1420388_at        -11.592618     0.95      -11.012988     4.609907
# 1460419_a_at      -11.866237     0.95      -11.272925     4.810493
# 1434295_at        -12.046629     0.95      -11.444298     4.945296
# 1435667_at        -12.265848     0.95      -11.652556     5.111851
# 1452227_at        -12.438546     0.95      -11.816619     5.245176
# 1424037_at        -12.489352     0.95      -11.864884     5.284754
# 1436275_at        -12.862342     0.95      -12.219225     5.580251
# 1428986_at        -12.948838     0.95      -12.301396     5.650019
# 1434653_at        -13.050655     0.95      -12.398122     5.732744
# 1436066_at        -14.020092     0.95      -13.319087     6.552849
# 1424852_at        -14.262935     0.95      -13.549789     6.767485
# 1455664_at        -16.176045     0.95      -15.367243     8.587270
# 1456487_at        -18.059756     0.95      -17.156769    10.602594
# 1443287_at        -20.635011     0.95      -19.603260    13.716621
# 1424248_at        -21.991879     0.95      -20.892285    15.524092
#
#               430V2_Var_g  430V2_SEg
# Probesets
# 1418603_at       9.851058   3.138640
# 1457265_at       8.592116   2.931231
# 1457396_at       7.619485   2.760341
# 1460006_at       7.368206   2.714444
# 1442809_at       6.320316   2.514024
# 1419408_at       6.135954   2.477086
# 1454731_at       4.543510   2.131551
# 1423726_at       4.412950   2.100702
# 1434073_at       4.165564   2.040971
# 1438729_at       4.084065   2.020907
# 1433577_at       3.993556   1.998388
# 1417704_a_at     3.879890   1.969744
# 1440564_at       3.855186   1.963463
# 1436484_at       3.719725   1.928659
# 1433452_at       3.549128   1.883913
# 1419428_a_at     3.378218   1.837993
# 1450708_at       3.316215   1.821048
# 1421899_a_at     3.097622   1.760006
# 1434594_at       3.060208   1.749345
# 1448188_at       3.052740   1.747209
# 1456333_a_at     3.010261   1.735010
# 1417011_at       3.007239   1.734139
# 1415964_at       2.973016   1.724244
# 1431812_a_at     2.874876   1.695546
# 1423422_at       2.867795   1.693457
# 1436913_at       2.866505   1.693076
# 1434857_at       2.860106   1.691185
# 1417217_at       2.737894   1.654658
# 1430699_at       2.713955   1.647409
# 1433749_at       2.671193   1.634379
# ...                   ...        ...
# 1452196_a_at     3.324380   1.823288
# 1417129_a_at     3.348063   1.829771
# 1455056_at       3.374193   1.836898
# 1441214_at       3.397273   1.843169
# 1455463_at       3.463864   1.861146
# 1455436_at       3.532602   1.879522
# 1452092_at       3.535166   1.880204
# 1440286_at       3.579314   1.891907
# 1418619_at       3.673063   1.916524
# 1417829_a_at     3.779909   1.944199
# 1459903_at       3.789862   1.946757
# 1455758_at       3.905889   1.976332
# 1455411_at       4.018149   2.004532
# 1455301_at       4.028686   2.007159
# 1452861_at       4.122310   2.030347
# 1420388_at       4.160441   2.039716
# 1460419_a_at     4.341470   2.083619
# 1434295_at       4.463130   2.112612
# 1435667_at       4.613446   2.147893
# 1452227_at       4.733771   2.175723
# 1424037_at       4.769490   2.183916
# 1436275_at       5.036177   2.244143
# 1428986_at       5.099142   2.258128
# 1434653_at       5.173801   2.274599
# 1436066_at       5.913947   2.431861
# 1424852_at       6.107655   2.471367
# 1455664_at       7.750011   2.783884
# 1456487_at       9.568841   3.093354
# 1443287_at      12.379250   3.518416
# 1424248_at      14.010493   3.743059
#
# [40569 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['Symbol', 'Definition', 'Ensembl_id', 'Entrez_id', 'Unigene_id',
#        'GO-Process', 'GO-Function', 'GO-Component', 'Pathway_info',
#        'Putative microRNA binding sites', 'Select Cellular Compartments',
#        'Select Protein Classes', 'GSM252077.CEL', 'GSM252078.CEL',
#        'GSM252079.CEL', 'GSM511616.CEL', 'GSM511617.CEL', 'GSM511618.CEL',
#        'GSM511619.CEL', 'GSM511620.CEL', 'GSM511621.CEL', 'GSM511622.CEL',
#        'GSM511623.CEL', 'GSM511624.CEL', 'GSM511625.CEL', 'avg-WB',
#        'GSM414571.CEL', 'GSM414572.CEL', 'GSM707557.CEL', 'avg-SCN',
#        'log_fold-SCN_vs_WB', 'fold-SCN_vs_WB', 'rawp-SCN_vs_WB',
#        'adjp-SCN_vs_WB', 'ANOVA-rawp', 'ANOVA-adjp', 'largest fold',
#        '430V2_Enrich', '430V2_poolStDev', '430V2_Cohens_d', '430V2_J',
#        '430V2_Hedges_g', '430V2_Var_d', '430V2_Var_g', '430V2_SEg'],
#       dtype='object')

# %%
dfX=pd.read_table('../BioMart_Ensmbl_index/mart_export72_430v2430Av2.txt',index_col=[2])

dfX.pop('Affy mouse430a 2 probeset') # remove 430Av2 IDs
dfX.head()
# Out:
#                              Ensembl Gene ID  \
# Affy mouse430 2 probeset
# 1417126_a_at              ENSMUSG00000039221
# NaN                       ENSMUSG00000095611
# 1417730_at                ENSMUSG00000061731
# 1417730_at                ENSMUSG00000061731
# 1458054_at                ENSMUSG00000061731
#
#                                                                 Description  \
# Affy mouse430 2 probeset
# 1417126_a_at              ribosomal protein L22 like 1 [Source:MGI Symbo...
# NaN                       predicted gene 10597 [Source:MGI Symbol;Acc:MG...
# 1417730_at                exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# 1417730_at                exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
# 1458054_at                exostoses (multiple) 1 [Source:MGI Symbol;Acc:...
#
#                          MGI symbol
# Affy mouse430 2 probeset
# 1417126_a_at                Rpl22l1
# NaN                         Gm10597
# 1417730_at                     Ext1
# 1417730_at                     Ext1
# 1458054_at                     Ext1

# %%
df_Join = df.join(dfX, how='left', sort=True)
df_FINAL1 = df_Join.groupby('MGI symbol').mean()
df_FINAL1[df_FINAL1.index.duplicated()==True]  #Check that no duplicate entries for symbol exist
# Out:
# Empty DataFrame
# Columns: [GSM252077.CEL, GSM252078.CEL, GSM252079.CEL, GSM511616.CEL, GSM511617.CEL, GSM511618.CEL, GSM511619.CEL, GSM511620.CEL, GSM511621.CEL, GSM511622.CEL, GSM511623.CEL, GSM511624.CEL, GSM511625.CEL, avg-WB, GSM414571.CEL, GSM414572.CEL, GSM707557.CEL, avg-SCN, log_fold-SCN_vs_WB, fold-SCN_vs_WB, rawp-SCN_vs_WB, adjp-SCN_vs_WB, ANOVA-rawp, ANOVA-adjp, largest fold, 430V2_Enrich, 430V2_poolStDev, 430V2_Cohens_d, 430V2_J, 430V2_Hedges_g, 430V2_Var_d, 430V2_Var_g, 430V2_SEg]
# Index: []
#
# [0 rows x 33 columns]

# %%
# df_FINAL2 = df_Join.groupby('Ensembl Gene ID').mean()   # If you wanted indexing by ENSMBL GID
# df_FINAL2[df_FINAL2.index.duplicated()==True]

# %% [markdown]
# ### Columns from the list above can then easily be picked to produce files for use later. Examples below given:
#  #### df3 = average SCN and WB expression for the platform and the log-fold changes
#  #### df4 = Hedges g  values and associated variance for Meta-analysis (after indexing)

# %%
# df3 = df_FINAL1.loc[:,[u'avg-WB', u'avg-SCN', u'log_fold-SCN_vs_WB']]
# df3.columns =[prefix+'avg-WB', prefix+'avg-SCN', prefix+'log_fold-SCN_vs_WB']
# df3.to_csv('input_files/430V2_SymbolExpression_forIndex.csv')

# %%
df4 = df_FINAL1.loc[:,[u'430V2_Enrich',u'430V2_Hedges_g', u'430V2_Var_g', u'430V2_SEg']]
df4.to_csv('input_files/430V2_SymbolforIndexHedges.csv')

# %%
df4
# Out:
#                430V2_Enrich  430V2_Hedges_g  430V2_Var_g  430V2_SEg
# MGI symbol
# 0610005C13Rik     -0.065548       -0.308451     0.373230   0.610925
# 0610008F07Rik     -0.029420       -0.177580     0.371242   0.609296
# 0610009B14Rik     -0.326035       -1.337117     0.426128   0.652785
# 0610009B22Rik      0.392765        1.473526     0.438109   0.661898
# 0610009D07Rik      0.052437        0.135410     0.370857   0.608980
# 0610009L18Rik     -0.192890       -0.611839     0.381955   0.618025
# 0610009O20Rik     -0.573090       -1.797072     0.471177   0.686424
# 0610010F05Rik      0.094879        0.093928     0.373384   0.611052
# 0610010K14Rik      0.180634        0.287394     0.372838   0.610604
# 0610011F06Rik      0.664020        2.707147     0.602898   0.775627
# 0610012G03Rik     -0.588596       -2.291471     0.560347   0.743410
# 0610012H03Rik     -0.247659       -1.057337     0.405193   0.636547
# 0610025J13Rik     -0.095674       -0.370732     0.374551   0.612006
# 0610030E20Rik     -0.113226       -0.494749     0.381878   0.617899
# 0610031J06Rik      0.463932        2.011979     0.496758   0.704811
# 0610037L13Rik     -0.078340       -0.723312     0.390435   0.624780
# 0610038L08Rik     -0.007362       -0.051028     0.370338   0.608554
# 0610039K10Rik     -0.149279       -0.911604     0.396226   0.629465
# 0610040B09Rik      0.170520        1.017330     0.402599   0.634507
# 0610040B10Rik      0.045686        0.094302     0.370534   0.608715
# 0610040F04Rik     -0.470368       -2.781527     0.612034   0.782326
# 0610040J01Rik     -0.436365       -2.174110     0.517967   0.719700
# 1100001G20Rik     -0.232795       -1.706011     0.461209   0.679123
# 1110001A16Rik     -0.420328       -0.847864     0.392721   0.626675
# 1110001J03Rik     -0.211217       -0.642156     0.383143   0.618985
# 1110002E22Rik     -0.606950       -4.609314     1.034187   1.016950
# 1110002L01Rik     -0.088517       -0.237963     0.372026   0.609939
# 1110004E09Rik      0.079273        0.203468     0.372511   0.610335
# 1110004F10Rik      0.684217        1.252712     0.419297   0.647531
# 1110006G14Rik     -0.011703       -0.067714     0.370400   0.608605
# ...                     ...             ...          ...        ...
# Zscan29            0.841825        2.456248     0.558792   0.747524
# Zscan4c           -0.072483       -0.351703     0.374122   0.611655
# Zscan4d           -0.072483       -0.351703     0.374122   0.611655
# Zscan4f           -0.072483       -0.351703     0.374122   0.611655
# Zscan5b           -0.049104       -0.306752     0.373197   0.610898
# Zswim1             0.139598        0.562097     0.380130   0.616547
# Zswim2            -0.428886       -1.609410     0.451397   0.671834
# Zswim3            -0.053521       -0.312460     0.373307   0.610989
# Zswim4            -0.054480       -0.312325     0.373305   0.610987
# Zswim5             0.021133        0.101680     0.370579   0.608752
# Zswim6            -0.582857       -3.701944     1.117957   0.988984
# Zswim7            -0.242491       -0.755634     0.388100   0.622976
# Zswim8             0.778129        2.637917     0.587713   0.766624
# Zufsp              0.154093        0.684546     0.384900   0.620403
# Zw10               0.141143        1.065808     0.405755   0.636989
# Zwilch            -0.124869       -1.143605     0.411126   0.641191
# Zwint              1.270096        2.234485     0.529092   0.726772
# Zxda               0.197812        0.813345     0.390929   0.625243
# Zxdb               0.197812        0.813345     0.390929   0.625243
# Zxdc              -0.006942       -0.038478     0.376362   0.613471
# Zyg11a            -0.141581       -0.825311     0.391542   0.625733
# Zyg11b            -0.404909       -0.903922     0.463780   0.675500
# Zyx               -0.258914       -0.769223     0.388747   0.623496
# Zzef1             -0.023488       -0.116510     0.371397   0.609422
# Zzz3               0.272576        1.046095     0.404454   0.635967
# a                 -0.155027       -0.720040     0.386458   0.621658
# l7Rn6              0.250799        0.698901     0.385796   0.621116
# n-R5s154          -0.376543       -3.462052     0.744813   0.863025
# n-R5s185           0.350648        0.875812     0.394227   0.627875
# n-R5s31           -0.089716       -0.441156     0.376338   0.613464
#
# [19669 rows x 4 columns]
